# %% [markdown]
# <a href="https://colab.research.google.com/github/Virajita28/traffic-sign-detection/blob/main/TrafficSignDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "virajitapanwar@gmail.com"
# !git config --global user.name "Virajita Panwar"

# %%
# !git clone https://github.com/Virajita28/traffic-sign-detection.git
# Out:
# Cloning into 'traffic-sign-detection'...
# ...

# %%
# !cp /content/TrafficSignDetection.ipynb /content/traffic-sign-detection/
# Out:
# cp: cannot stat '/content/TrafficSignDetection.ipynb': No such file or directory

# %%
# !cp /content/my_notebook.ipynb /content/traffic-sign-detection/
# Out:
# cp: cannot stat '/content/my_notebook.ipynb': No such file or directory

# %%
# !ls /content
# Out:
# sample_data  traffic-sign-detection

# %%
import shutil

# %%
import os
import os
if 'COLAB_GPU' in os.environ:
  print("GPU is enabled")
else:
  print("GPU is not enabled!")
# Out:
# GPU is enabled

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.4/910.4 kB 40.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.64 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection  sample_data

# %%
path ="content/RoadSignDetection"

# %%
# %pwd
# Out:
# '/content'

# %%
import os
os.chdir("/content/RoadSignDetection")

# %%
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SYqA4nWhV4Or1cO5selq")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:01<00:00, 7275.31it/s]

# %%
os.chdir("/content/RoadSignDetection/Self-Driving-Cars-6")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 146MB/s]
# Ultralytics 8.3.64 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
pip install yolov8
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.5/953.5 kB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 103.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=cf49fa572ac1f58e17af2c2b7b9963e9da0f42c8064fda489249ca2b24ea68d2
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...
#   Attempting uninstall: huggingface-hub
# ...

# %%
os.chdir("/content/RoadSignDetection/Self-Driving-Cars-6")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.64 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls '/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train2'
# Out:
# args.yaml					    labels.jpg	      train_batch1.jpg
# events.out.tfevents.1737390072.9115eb9d8cb1.5601.0  results.csv       train_batch2.jpg
# labels_correlogram.jpg				    train_batch0.jpg  weights

# %%
resultData="/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train2/"
from IPython.display import Image, display
Image(filename=f'{resultData}confusion_matrix.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-8dfb4b68b7a9> in <cell line: 0>()
#       1 resultData="/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train2/"
#       2 from IPython.display import Image, display
# ----> 3 Image(filename=f'{resultData}confusion_matrix.png')
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# ...

# %%
Image(filename=f'{resultData}results.png')

# %%
import pandas as pd
df=pd.read_csv(f'{resultData}results.csv')
print(df.tail(5))
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 5      6  436.775         0.63731         1.16437         0.99230
# 6      7  507.720         0.62073         1.00448         0.97568
# 7      8  577.606         0.59196         0.90038         0.95880
# 8      9  647.794         0.57644         0.81997         0.94800
# 9     10  718.141         0.55356         0.76024         0.94263
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 5               0.88144            0.80188           0.88219
# 6               0.91797            0.79920           0.88877
# 7               0.91523            0.82180           0.89738
# 8               0.92881            0.84091           0.91894
# 9               0.93127            0.83283           0.91477
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 5              0.74632       0.64401       0.67832       0.99044  0.000266
# ...

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/Self-Driving-Cars-6'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir ManualTestingData

# %%
weightsPath= "/content/RoadSignDetection/Self-Driving-Cars-6/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=0.25 source= '/content/ManualTestingData/inputVideo1.mp4' save=True
# Out:
# Ultralytics 8.3.61 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 37.6ms
# video 1/1 (frame 2/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.1ms
# video 1/1 (frame 3/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 9.5ms
# video 1/1 (frame 4/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.7ms
# video 1/1 (frame 5/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.1ms
# video 1/1 (frame 6/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.0ms
# video 1/1 (frame 7/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.8ms
# video 1/1 (frame 8/421) /content/ManualTestingData/inputVideo1.mp4: 352x640 1 Stop, 10.1ms
# ...

# %%
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=0.25 source= '/content/ManualTestingData/inputImage3.jpg' save=True
# Out:
# Ultralytics 8.3.61 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/ManualTestingData/inputImage3.jpg: 448x640 2 Red Lights, 51.1ms
# Speed: 5.3ms preprocess, 51.1ms inference, 995.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files
files.download('/content/runs/detect/predict2/inputImage3.jpg')
files.download('/content/runs/detect/predict/inputVideo1.avi')

# %%
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=0.25 source= '/content/ManualTestingData/signdetection1.mp4' save=True
# Out:
# Ultralytics 8.3.61 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 34.7ms
# video 1/1 (frame 2/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 9.9ms
# video 1/1 (frame 3/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 10.3ms
# video 1/1 (frame 4/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 9.8ms
# video 1/1 (frame 5/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 9.8ms
# video 1/1 (frame 6/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 9.3ms
# video 1/1 (frame 7/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 10.8ms
# video 1/1 (frame 8/529) /content/ManualTestingData/signdetection1.mp4: 384x640 1 Red Light, 10.0ms
# ...
